# %%
# !pip install -q piper-tts pathvalidate soundfile librosa datasets transformers accelerate bitsandbytes
# Out:
#    â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 13.8/13.8 MB 65.8 MB/s eta 0:00:00
#    â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 17.1/17.1 MB 71.5 MB/s eta 0:00:00

# %%
# !python -m piper.download_voices en_US-lessac-medium
# Out:
# INFO:__main__:Downloaded: en_US-lessac-medium

# %%
import os
import json
import subprocess
import torch
from tqdm import tqdm
import soundfile as sf
import librosa

from datasets import load_dataset
from transformers import AutoProcessor, AutoModelForTextToWaveform, BitsAndBytesConfig

# ---------------- CONFIG -------------------
HF_DATASET = "frostymelonade/SemEval2017-task7-pun-detection"
HF_SPLIT = "test"

TYPES = {"heterographic", "homographic"}

MODEL_ID = "Qwen/Qwen3-Omni-30B-A3B-Instruct"
MAX_NEW_TOKENS = 120

PIPER_MODEL = os.environ.get("PIPER_MODEL", "piper_models/en_US-lessac-medium.onnx")
AUDIO_DIR = "cache/tts"
AUDIO_EXT = ".wav"

OUT_BASE = "cache/phase3_text_audio_raw"
OUT_ALL = OUT_BASE + ".jsonl"
OUT_HET = OUT_BASE + ".heterographic.jsonl"
OUT_HOM = OUT_BASE + ".homographic.jsonl"

os.makedirs(AUDIO_DIR, exist_ok=True)
os.makedirs("cache", exist_ok=True)

# ---------------- PROMPT ----------------

AUDIO_PROMPT_TEMPLATE = """Explain whether the following text contains a pun.

You are given the written text and its spoken audio.

Instructions:
- Do NOT explain your analysis process.
- Do NOT define what a pun is.
- Focus ONLY on the linguistic mechanism.
- If the text is a pun, clearly state:
  â€¢ the word or phrase involved
  â€¢ the two meanings or sound-based ambiguity
- If it is not a pun, clearly state that no wordplay or ambiguity is present.

Write a concise paragraph (3â€“6 sentences).

Text:
{text}
"""

def build_messages(text, audio_path):
    return [
        {"role": "system", "content": "You are an expert linguist."},
        {
            "role": "user",
            "content": [
                {"type": "audio", "audio_url": audio_path},
                {"type": "text", "text": AUDIO_PROMPT_TEMPLATE.format(text=text)},
            ],
        }
    ]


# ---------------- HELPERS ----------------
def normalize_id(x):
    return str(x).strip() if x else None

def load_audio(path, target_sr=16000):
    wav, sr = sf.read(path)
    if sr != target_sr:
        wav = librosa.resample(wav, orig_sr=sr, target_sr=target_sr)
    return wav



#------------------PHASE A - OFFLINE TTS----------------
print("=== Phase A: Generating TTS ===")

ds = load_dataset(HF_DATASET, split=HF_SPLIT)

items = []
for r in ds:
    if r["type"] in TYPES:
        items.append({
            "id": normalize_id(r["id"]),
            "text": r["text"],
            "type": r["type"],
            "label": r["label"],
        })

grouped = {}
for x in items:
    grouped.setdefault(x["type"], []).append(x)

items = []
for t in sorted(grouped.keys()):
    items.extend(grouped[t])

def generate_tts(text, uid):
    out_wav = os.path.join(AUDIO_DIR, uid + AUDIO_EXT)

    if os.path.exists(out_wav) and os.path.getsize(out_wav) > 1000:
        return True

    p = subprocess.run(
        [
            "piper",
            "--model", PIPER_MODEL,
            "--output_file", out_wav,
        ],
        input=text + "\n",
        text=True,
        capture_output=True,
    )

    if p.returncode != 0:
        print(f"[PIPER ERROR] {uid}")
        print(p.stderr)
        return False

    if not os.path.exists(out_wav) or os.path.getsize(out_wav) < 1000:
        return False

    return True

ok = 0
for it in tqdm(items, desc="TTS"):
    if generate_tts(it["text"], it["id"]):
        ok += 1

print(f"TTS generated for {ok}/{len(items)} items")

# ---------------VERIFY WAVS---------------
bad = []
for fn in os.listdir(AUDIO_DIR):
    try:
        info = sf.info(os.path.join(AUDIO_DIR, fn))
        if info.frames == 0:
            bad.append(fn)
    except:
        bad.append(fn)

print("Bad wav files:", len(bad))
assert len(bad) == 0, "Some WAV files are invalid"


#-------------------PHASE B â€” QWEN3-OMNI-------------------
print("=== Phase B: Qwen3-Omni inference ===")

device = "cuda"
torch.set_grad_enabled(False)

quantization_config = BitsAndBytesConfig(load_in_8bit=True)

processor = AutoProcessor.from_pretrained(MODEL_ID)
model = AutoModelForTextToWaveform.from_pretrained(
    MODEL_ID,
    quantization_config=quantization_config,
    device_map="auto",
    torch_dtype="auto",
).eval()

def generate_reason(text, uid):
    wav_path = os.path.join(AUDIO_DIR, uid + AUDIO_EXT)
    messages = build_messages(text, wav_path)

    prompt = processor.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
    )

    audio = load_audio(wav_path)

    inputs = processor(
        text=prompt,
        audios=[audio],
        sampling_rate=16000,
        return_tensors="pt",
        padding=True,
    ).to(model.device)

    out = model.generate(
        **inputs,
        max_new_tokens=MAX_NEW_TOKENS,
        min_new_tokens=40,
        do_sample=False,
        return_audio=False,
    )

    return processor.batch_decode(
        out[:, inputs["input_ids"].shape[1]:],
        skip_special_tokens=True,
    )[0].strip()

os.makedirs(os.path.dirname(OUT_ALL), exist_ok=True)

with open(OUT_ALL, "w", encoding="utf-8") as fa, \
     open(OUT_HET, "w", encoding="utf-8") as fh, \
     open(OUT_HOM, "w", encoding="utf-8") as fm:

    for it in tqdm(items, desc="Inference"):
        uid = it["id"]
        wav = os.path.join(AUDIO_DIR, uid + AUDIO_EXT)
        if not os.path.exists(wav):
            continue

        reason = generate_reason(it["text"], uid)

        obj = {
            "id": uid,
            "Text": it["text"],
            "RawReason": reason,
            "Label": it["label"],
            "Type": it["type"],
        }

        line = json.dumps(obj, ensure_ascii=False) + "\n"
        fa.write(line)
        (fh if it["type"] == "heterographic" else fm).write(line)

print("=== DONE: Text + Audio experiment complete ===")
# Out:
# === Phase A: Generating TTS ===
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/101 [00:00<?, ?B/s]
# heterographic-and-homographic-test.json: 0.00B [00:00, ?B/s]
# Generating test split:   0%|          | 0/4030 [00:00<?, ? examples/s]
# TTS: 100%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ| 500/500 [18:38<00:00,  2.24s/it]
# TTS generated for 500/500 items
# Bad wav files: 0
# === Phase B: Qwen2-Audio inference ===
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/853 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/876 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# Inference:   0%|          | 0/500 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#
# Inference:   0%|          | 1/500 [00:16<2:19:42, 16.80s/it]
# Inference:   0%|          | 2/500 [00:22<1:24:34, 10.19s/it]
# Inference:   1%|          | 3/500 [00:25<57:54,  6.99s/it]
# Inference:   1%|          | 4/500 [00:30<50:03,  6.06s/it]
# Inference:   1%|          | 5/500 [00:34<44:37,  5.41s/it]
# Inference:   1%|          | 6/500 [00:38<41:40,  5.06s/it]
# Inference:   1%|â–         | 7/500 [00:44<43:57,  5.35s/it]
# Inference:   2%|â–         | 8/500 [00:47<38:19,  4.67s/it]
# Inference:   2%|â–         | 9/500 [00:51<36:12,  4.42s/it]
# Inference:   2%|â–         | 10/500 [00:55<33:24,  4.09s/it]
# Inference:   2%|â–         | 11/500 [00:58<30:23,  3.73s/it]
# Inference:   2%|â–         | 12/500 [01:01<29:03,  3.57s/it]
# Inference:   3%|â–Ž         | 13/500 [01:04<27:11,  3.35s/it]
# Inference:   3%|â–Ž         | 14/500 [01:08<28:38,  3.54s/it]
# Inference:   3%|â–Ž         | 15/500 [01:11<29:01,  3.59s/it]
# Inference:   3%|â–Ž         | 16/500 [01:14<26:41,  3.31s/it]
# Inference:   3%|â–Ž         | 17/500 [01:17<25:07,  3.12s/it]
# Inference:   4%|â–Ž         | 18/500 [01:22<31:11,  3.88s/it]
# Inference:   4%|â–         | 19/500 [01:26<30:14,  3.77s/it]
# Inference:   4%|â–         | 20/500 [01:29<29:04,  3.63s/it]
# Inference:   4%|â–         | 21/500 [01:34<31:35,  3.96s/it]
# Inference:   4%|â–         | 22/500 [01:37<28:34,  3.59s/it]
# Inference:   5%|â–         | 23/500 [01:42<33:54,  4.27s/it]
# Inference:   5%|â–         | 24/500 [01:49<38:27,  4.85s/it]
# Inference:   5%|â–Œ         | 25/500 [01:52<34:33,  4.37s/it]
# Inference:   5%|â–Œ         | 26/500 [01:58<37:33,  4.75s/it]
# Inference:   5%|â–Œ         | 27/500 [02:02<37:24,  4.75s/it]
# Inference:   6%|â–Œ         | 28/500 [02:05<32:54,  4.18s/it]
# Inference:   6%|â–Œ         | 29/500 [02:09<31:39,  4.03s/it]
# Inference:   6%|â–Œ         | 30/500 [02:12<30:17,  3.87s/it]
# Inference:   6%|â–Œ         | 31/500 [02:16<29:55,  3.83s/it]
# Inference:   6%|â–‹         | 32/500 [02:19<28:29,  3.65s/it]
# Inference:   7%|â–‹         | 33/500 [02:23<28:20,  3.64s/it]
# Inference:   7%|â–‹         | 34/500 [02:29<33:28,  4.31s/it]
# Inference:   7%|â–‹         | 35/500 [02:33<32:56,  4.25s/it]
# Inference:   7%|â–‹         | 36/500 [02:37<31:25,  4.06s/it]
# Inference:   7%|â–‹         | 37/500 [02:41<31:57,  4.14s/it]
# Inference:   8%|â–Š         | 38/500 [02:44<28:33,  3.71s/it]
# Inference:   8%|â–Š         | 39/500 [02:48<29:27,  3.83s/it]
# Inference:   8%|â–Š         | 40/500 [02:50<26:45,  3.49s/it]
# Inference:   8%|â–Š         | 41/500 [02:56<32:28,  4.24s/it]
# Inference:   8%|â–Š         | 42/500 [03:00<30:33,  4.00s/it]
# Inference:   9%|â–Š         | 43/500 [03:06<36:09,  4.75s/it]
# Inference:   9%|â–‰         | 44/500 [03:10<32:40,  4.30s/it]
# Inference:   9%|â–‰         | 45/500 [03:14<31:53,  4.21s/it]
# Inference:   9%|â–‰         | 46/500 [03:18<31:17,  4.14s/it]
# Inference:   9%|â–‰         | 47/500 [03:20<28:11,  3.73s/it]
# Inference:  10%|â–‰         | 48/500 [03:24<27:10,  3.61s/it]
# Inference:  10%|â–‰         | 49/500 [03:27<25:57,  3.45s/it]
# Inference:  10%|â–ˆ         | 50/500 [03:31<28:30,  3.80s/it]
# Inference:  10%|â–ˆ         | 51/500 [03:37<31:49,  4.25s/it]
# Inference:  10%|â–ˆ         | 52/500 [03:42<34:07,  4.57s/it]
# Inference:  11%|â–ˆ         | 53/500 [03:48<38:17,  5.14s/it]
# Inference:  11%|â–ˆ         | 54/500 [03:52<33:38,  4.53s/it]
# Inference:  11%|â–ˆ         | 55/500 [03:55<31:59,  4.31s/it]
# Inference:  11%|â–ˆ         | 56/500 [03:58<28:19,  3.83s/it]
# Inference:  11%|â–ˆâ–        | 57/500 [04:03<31:20,  4.25s/it]
# Inference:  12%|â–ˆâ–        | 58/500 [04:07<30:43,  4.17s/it]
# Inference:  12%|â–ˆâ–        | 59/500 [04:12<31:15,  4.25s/it]
# Inference:  12%|â–ˆâ–        | 60/500 [04:18<35:32,  4.85s/it]
# Inference:  12%|â–ˆâ–        | 61/500 [04:21<32:27,  4.44s/it]
# Inference:  12%|â–ˆâ–        | 62/500 [04:24<29:15,  4.01s/it]
# Inference:  13%|â–ˆâ–Ž        | 63/500 [04:27<26:51,  3.69s/it]
# Inference:  13%|â–ˆâ–Ž        | 64/500 [04:31<25:56,  3.57s/it]
# Inference:  13%|â–ˆâ–Ž        | 65/500 [04:33<24:12,  3.34s/it]
# Inference:  13%|â–ˆâ–Ž        | 66/500 [04:40<31:49,  4.40s/it]
# Inference:  13%|â–ˆâ–Ž        | 67/500 [04:45<33:02,  4.58s/it]
# Inference:  14%|â–ˆâ–Ž        | 68/500 [04:49<30:11,  4.19s/it]
# Inference:  14%|â–ˆâ–        | 69/500 [04:53<31:35,  4.40s/it]
# Inference:  14%|â–ˆâ–        | 70/500 [04:59<32:57,  4.60s/it]
# Inference:  14%|â–ˆâ–        | 71/500 [05:02<30:40,  4.29s/it]
# Inference:  14%|â–ˆâ–        | 72/500 [05:06<29:09,  4.09s/it]
# Inference:  15%|â–ˆâ–        | 73/500 [05:11<31:18,  4.40s/it]
# Inference:  15%|â–ˆâ–        | 74/500 [05:16<33:26,  4.71s/it]
# Inference:  15%|â–ˆâ–Œ        | 75/500 [05:21<32:53,  4.64s/it]
# Inference:  15%|â–ˆâ–Œ        | 76/500 [05:25<31:58,  4.52s/it]
# Inference:  15%|â–ˆâ–Œ        | 77/500 [05:28<29:07,  4.13s/it]
# Inference:  16%|â–ˆâ–Œ        | 78/500 [05:31<26:25,  3.76s/it]
# Inference:  16%|â–ˆâ–Œ        | 79/500 [05:34<24:50,  3.54s/it]
# Inference:  16%|â–ˆâ–Œ        | 80/500 [05:39<27:10,  3.88s/it]
# Inference:  16%|â–ˆâ–Œ        | 81/500 [05:45<31:03,  4.45s/it]
# Inference:  16%|â–ˆâ–‹        | 82/500 [05:48<28:26,  4.08s/it]
# Inference:  17%|â–ˆâ–‹        | 83/500 [05:53<30:55,  4.45s/it]
# Inference:  17%|â–ˆâ–‹        | 84/500 [05:57<29:54,  4.31s/it]
# Inference:  17%|â–ˆâ–‹        | 85/500 [06:01<28:01,  4.05s/it]
# Inference:  17%|â–ˆâ–‹        | 86/500 [06:08<35:19,  5.12s/it]
# Inference:  17%|â–ˆâ–‹        | 87/500 [06:12<33:17,  4.84s/it]
# Inference:  18%|â–ˆâ–Š        | 88/500 [06:16<30:40,  4.47s/it]
# Inference:  18%|â–ˆâ–Š        | 89/500 [06:20<30:15,  4.42s/it]
# Inference:  18%|â–ˆâ–Š        | 90/500 [06:24<28:38,  4.19s/it]
# Inference:  18%|â–ˆâ–Š        | 91/500 [06:28<28:39,  4.20s/it]
# Inference:  18%|â–ˆâ–Š        | 92/500 [06:31<26:27,  3.89s/it]
# Inference:  19%|â–ˆâ–Š        | 93/500 [06:38<31:32,  4.65s/it]
# Inference:  19%|â–ˆâ–‰        | 94/500 [06:41<28:15,  4.18s/it]
# Inference:  19%|â–ˆâ–‰        | 95/500 [06:44<26:48,  3.97s/it]
# Inference:  19%|â–ˆâ–‰        | 96/500 [06:47<25:06,  3.73s/it]
# Inference:  19%|â–ˆâ–‰        | 97/500 [06:52<27:34,  4.11s/it]
# Inference:  20%|â–ˆâ–‰        | 98/500 [06:55<24:53,  3.72s/it]
# Inference:  20%|â–ˆâ–‰        | 99/500 [06:59<24:36,  3.68s/it]
# Inference:  20%|â–ˆâ–ˆ        | 100/500 [07:05<28:46,  4.32s/it]
# Inference:  20%|â–ˆâ–ˆ        | 101/500 [07:08<26:49,  4.03s/it]
# Inference:  20%|â–ˆâ–ˆ        | 102/500 [07:13<28:32,  4.30s/it]
# Inference:  21%|â–ˆâ–ˆ        | 103/500 [07:17<27:57,  4.23s/it]
# Inference:  21%|â–ˆâ–ˆ        | 104/500 [07:22<28:48,  4.36s/it]
# Inference:  21%|â–ˆâ–ˆ        | 105/500 [07:25<26:53,  4.08s/it]
# Inference:  21%|â–ˆâ–ˆ        | 106/500 [07:28<24:56,  3.80s/it]
# Inference:  21%|â–ˆâ–ˆâ–       | 107/500 [07:32<25:15,  3.86s/it]
# Inference:  22%|â–ˆâ–ˆâ–       | 108/500 [07:35<23:56,  3.67s/it]
# Inference:  22%|â–ˆâ–ˆâ–       | 109/500 [07:39<23:40,  3.63s/it]
# Inference:  22%|â–ˆâ–ˆâ–       | 110/500 [07:44<26:36,  4.09s/it]
# Inference:  22%|â–ˆâ–ˆâ–       | 111/500 [07:48<25:09,  3.88s/it]
# Inference:  22%|â–ˆâ–ˆâ–       | 112/500 [07:50<23:07,  3.57s/it]
# Inference:  23%|â–ˆâ–ˆâ–Ž       | 113/500 [07:56<27:07,  4.20s/it]
# Inference:  23%|â–ˆâ–ˆâ–Ž       | 114/500 [08:00<25:40,  3.99s/it]
# Inference:  23%|â–ˆâ–ˆâ–Ž       | 115/500 [08:03<24:36,  3.84s/it]
# Inference:  23%|â–ˆâ–ˆâ–Ž       | 116/500 [08:09<28:03,  4.39s/it]
# Inference:  23%|â–ˆâ–ˆâ–Ž       | 117/500 [08:12<26:18,  4.12s/it]
# Inference:  24%|â–ˆâ–ˆâ–Ž       | 118/500 [08:16<26:14,  4.12s/it]
# Inference:  24%|â–ˆâ–ˆâ–       | 119/500 [08:23<31:08,  4.90s/it]
# Inference:  24%|â–ˆâ–ˆâ–       | 120/500 [08:28<31:55,  5.04s/it]
# Inference:  24%|â–ˆâ–ˆâ–       | 121/500 [08:31<27:34,  4.37s/it]
# Inference:  24%|â–ˆâ–ˆâ–       | 122/500 [08:34<25:01,  3.97s/it]
# Inference:  25%|â–ˆâ–ˆâ–       | 123/500 [08:38<23:58,  3.81s/it]
# Inference:  25%|â–ˆâ–ˆâ–       | 124/500 [08:41<21:58,  3.51s/it]
# Inference:  25%|â–ˆâ–ˆâ–Œ       | 125/500 [08:45<24:00,  3.84s/it]
# Inference:  25%|â–ˆâ–ˆâ–Œ       | 126/500 [08:48<22:13,  3.57s/it]
# Inference:  25%|â–ˆâ–ˆâ–Œ       | 127/500 [08:53<24:13,  3.90s/it]
# Inference:  26%|â–ˆâ–ˆâ–Œ       | 128/500 [08:56<22:23,  3.61s/it]
# Inference:  26%|â–ˆâ–ˆâ–Œ       | 129/500 [09:00<22:54,  3.70s/it]
# Inference:  26%|â–ˆâ–ˆâ–Œ       | 130/500 [09:03<22:15,  3.61s/it]
# Inference:  26%|â–ˆâ–ˆâ–Œ       | 131/500 [09:10<27:43,  4.51s/it]
# Inference:  26%|â–ˆâ–ˆâ–‹       | 132/500 [09:13<25:47,  4.21s/it]
# Inference:  27%|â–ˆâ–ˆâ–‹       | 133/500 [09:19<28:29,  4.66s/it]
# Inference:  27%|â–ˆâ–ˆâ–‹       | 134/500 [09:22<25:22,  4.16s/it]
# Inference:  27%|â–ˆâ–ˆâ–‹       | 135/500 [09:26<24:39,  4.05s/it]
# Inference:  27%|â–ˆâ–ˆâ–‹       | 136/500 [09:28<22:14,  3.67s/it]
# Inference:  27%|â–ˆâ–ˆâ–‹       | 137/500 [09:31<21:01,  3.47s/it]
# Inference:  28%|â–ˆâ–ˆâ–Š       | 138/500 [09:36<22:23,  3.71s/it]
# Inference:  28%|â–ˆâ–ˆâ–Š       | 139/500 [09:42<26:16,  4.37s/it]
# Inference:  28%|â–ˆâ–ˆâ–Š       | 140/500 [09:45<25:22,  4.23s/it]
# Inference:  28%|â–ˆâ–ˆâ–Š       | 141/500 [09:49<23:40,  3.96s/it]
# Inference:  28%|â–ˆâ–ˆâ–Š       | 142/500 [09:52<22:24,  3.76s/it]
# Inference:  29%|â–ˆâ–ˆâ–Š       | 143/500 [09:56<23:08,  3.89s/it]
# Inference:  29%|â–ˆâ–ˆâ–‰       | 144/500 [10:02<26:04,  4.39s/it]
# Inference:  29%|â–ˆâ–ˆâ–‰       | 145/500 [10:06<25:21,  4.28s/it]
# Inference:  29%|â–ˆâ–ˆâ–‰       | 146/500 [10:11<26:41,  4.52s/it]
# Inference:  29%|â–ˆâ–ˆâ–‰       | 147/500 [10:16<27:57,  4.75s/it]
# Inference:  30%|â–ˆâ–ˆâ–‰       | 148/500 [10:20<25:49,  4.40s/it]
# Inference:  30%|â–ˆâ–ˆâ–‰       | 149/500 [10:25<27:03,  4.62s/it]
# Inference:  30%|â–ˆâ–ˆâ–ˆ       | 150/500 [10:28<23:49,  4.08s/it]
# Inference:  30%|â–ˆâ–ˆâ–ˆ       | 151/500 [10:33<24:56,  4.29s/it]
# Inference:  30%|â–ˆâ–ˆâ–ˆ       | 152/500 [10:37<25:41,  4.43s/it]
# Inference:  31%|â–ˆâ–ˆâ–ˆ       | 153/500 [10:40<22:55,  3.96s/it]
# Inference:  31%|â–ˆâ–ˆâ–ˆ       | 154/500 [10:46<26:16,  4.56s/it]
# Inference:  31%|â–ˆâ–ˆâ–ˆ       | 155/500 [10:53<30:02,  5.23s/it]
# Inference:  31%|â–ˆâ–ˆâ–ˆ       | 156/500 [10:56<26:41,  4.66s/it]
# Inference:  31%|â–ˆâ–ˆâ–ˆâ–      | 157/500 [10:59<23:46,  4.16s/it]
# Inference:  32%|â–ˆâ–ˆâ–ˆâ–      | 158/500 [11:02<21:25,  3.76s/it]
# Inference:  32%|â–ˆâ–ˆâ–ˆâ–      | 159/500 [11:06<21:16,  3.74s/it]
# Inference:  32%|â–ˆâ–ˆâ–ˆâ–      | 160/500 [11:09<19:38,  3.47s/it]
# Inference:  32%|â–ˆâ–ˆâ–ˆâ–      | 161/500 [11:12<19:15,  3.41s/it]
# Inference:  32%|â–ˆâ–ˆâ–ˆâ–      | 162/500 [11:15<18:43,  3.32s/it]
# Inference:  33%|â–ˆâ–ˆâ–ˆâ–Ž      | 163/500 [11:19<19:16,  3.43s/it]
# Inference:  33%|â–ˆâ–ˆâ–ˆâ–Ž      | 164/500 [11:22<18:30,  3.30s/it]
# Inference:  33%|â–ˆâ–ˆâ–ˆâ–Ž      | 165/500 [11:26<19:19,  3.46s/it]
# Inference:  33%|â–ˆâ–ˆâ–ˆâ–Ž      | 166/500 [11:30<21:39,  3.89s/it]
# Inference:  33%|â–ˆâ–ˆâ–ˆâ–Ž      | 167/500 [11:33<20:01,  3.61s/it]
# Inference:  34%|â–ˆâ–ˆâ–ˆâ–Ž      | 168/500 [11:39<22:31,  4.07s/it]
# Inference:  34%|â–ˆâ–ˆâ–ˆâ–      | 169/500 [11:42<20:54,  3.79s/it]
# Inference:  34%|â–ˆâ–ˆâ–ˆâ–      | 170/500 [11:45<19:46,  3.59s/it]
# Inference:  34%|â–ˆâ–ˆâ–ˆâ–      | 171/500 [11:50<21:37,  3.94s/it]
# Inference:  34%|â–ˆâ–ˆâ–ˆâ–      | 172/500 [11:54<22:50,  4.18s/it]
# Inference:  35%|â–ˆâ–ˆâ–ˆâ–      | 173/500 [12:00<24:58,  4.58s/it]
# Inference:  35%|â–ˆâ–ˆâ–ˆâ–      | 174/500 [12:03<22:56,  4.22s/it]
# Inference:  35%|â–ˆâ–ˆâ–ˆâ–Œ      | 175/500 [12:07<22:38,  4.18s/it]
# Inference:  35%|â–ˆâ–ˆâ–ˆâ–Œ      | 176/500 [12:12<23:19,  4.32s/it]
# Inference:  35%|â–ˆâ–ˆâ–ˆâ–Œ      | 177/500 [12:18<26:13,  4.87s/it]
# Inference:  36%|â–ˆâ–ˆâ–ˆâ–Œ      | 178/500 [12:23<26:40,  4.97s/it]
# Inference:  36%|â–ˆâ–ˆâ–ˆâ–Œ      | 179/500 [12:28<26:39,  4.98s/it]
# Inference:  36%|â–ˆâ–ˆâ–ˆâ–Œ      | 180/500 [12:31<23:31,  4.41s/it]
# Inference:  36%|â–ˆâ–ˆâ–ˆâ–Œ      | 181/500 [12:37<25:17,  4.76s/it]
# Inference:  36%|â–ˆâ–ˆâ–ˆâ–‹      | 182/500 [12:40<22:39,  4.27s/it]
# Inference:  37%|â–ˆâ–ˆâ–ˆâ–‹      | 183/500 [12:46<25:21,  4.80s/it]
# Inference:  37%|â–ˆâ–ˆâ–ˆâ–‹      | 184/500 [12:52<26:54,  5.11s/it]
# Inference:  37%|â–ˆâ–ˆâ–ˆâ–‹      | 185/500 [12:57<26:28,  5.04s/it]
# Inference:  37%|â–ˆâ–ˆâ–ˆâ–‹      | 186/500 [13:05<30:36,  5.85s/it]
# Inference:  37%|â–ˆâ–ˆâ–ˆâ–‹      | 187/500 [13:09<28:13,  5.41s/it]
# Inference:  38%|â–ˆâ–ˆâ–ˆâ–Š      | 188/500 [13:14<28:12,  5.42s/it]
# Inference:  38%|â–ˆâ–ˆâ–ˆâ–Š      | 189/500 [13:20<28:15,  5.45s/it]
# Inference:  38%|â–ˆâ–ˆâ–ˆâ–Š      | 190/500 [13:24<25:22,  4.91s/it]
# Inference:  38%|â–ˆâ–ˆâ–ˆâ–Š      | 191/500 [13:28<24:42,  4.80s/it]
# Inference:  38%|â–ˆâ–ˆâ–ˆâ–Š      | 192/500 [13:35<27:07,  5.28s/it]
# Inference:  39%|â–ˆâ–ˆâ–ˆâ–Š      | 193/500 [13:38<23:44,  4.64s/it]
# Inference:  39%|â–ˆâ–ˆâ–ˆâ–‰      | 194/500 [13:42<23:52,  4.68s/it]
# Inference:  39%|â–ˆâ–ˆâ–ˆâ–‰      | 195/500 [13:47<22:54,  4.51s/it]
# Inference:  39%|â–ˆâ–ˆâ–ˆâ–‰      | 196/500 [13:52<23:38,  4.66s/it]
# Inference:  39%|â–ˆâ–ˆâ–ˆâ–‰      | 197/500 [13:55<21:32,  4.27s/it]
# Inference:  40%|â–ˆâ–ˆâ–ˆâ–‰      | 198/500 [14:00<23:11,  4.61s/it]
# Inference:  40%|â–ˆâ–ˆâ–ˆâ–‰      | 199/500 [14:03<20:31,  4.09s/it]
# Inference:  40%|â–ˆâ–ˆâ–ˆâ–ˆ      | 200/500 [14:08<20:55,  4.18s/it]
# Inference:  40%|â–ˆâ–ˆâ–ˆâ–ˆ      | 201/500 [14:11<19:34,  3.93s/it]
# Inference:  40%|â–ˆâ–ˆâ–ˆâ–ˆ      | 202/500 [14:17<22:27,  4.52s/it]
# Inference:  41%|â–ˆâ–ˆâ–ˆâ–ˆ      | 203/500 [14:21<21:10,  4.28s/it]
# Inference:  41%|â–ˆâ–ˆâ–ˆâ–ˆ      | 204/500 [14:24<19:28,  3.95s/it]
# Inference:  41%|â–ˆâ–ˆâ–ˆâ–ˆ      | 205/500 [14:27<18:41,  3.80s/it]
# Inference:  41%|â–ˆâ–ˆâ–ˆâ–ˆ      | 206/500 [14:32<19:36,  4.00s/it]
# Inference:  41%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 207/500 [14:37<21:01,  4.31s/it]
# Inference:  42%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 208/500 [14:41<20:43,  4.26s/it]
# Inference:  42%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 209/500 [14:46<22:17,  4.60s/it]
# Inference:  42%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 210/500 [14:50<20:21,  4.21s/it]
# Inference:  42%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 211/500 [14:55<21:37,  4.49s/it]
# Inference:  42%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 212/500 [14:58<19:18,  4.02s/it]
# Inference:  43%|â–ˆâ–ˆâ–ˆâ–ˆâ–Ž     | 213/500 [15:03<20:59,  4.39s/it]
# Inference:  43%|â–ˆâ–ˆâ–ˆâ–ˆâ–Ž     | 214/500 [15:07<19:54,  4.18s/it]
# Inference:  43%|â–ˆâ–ˆâ–ˆâ–ˆâ–Ž     | 215/500 [15:10<19:00,  4.00s/it]
# Inference:  43%|â–ˆâ–ˆâ–ˆâ–ˆâ–Ž     | 216/500 [15:13<17:04,  3.61s/it]
# Inference:  43%|â–ˆâ–ˆâ–ˆâ–ˆâ–Ž     | 217/500 [15:16<16:24,  3.48s/it]
# Inference:  44%|â–ˆâ–ˆâ–ˆâ–ˆâ–Ž     | 218/500 [15:22<19:16,  4.10s/it]
# Inference:  44%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 219/500 [15:24<17:28,  3.73s/it]
# Inference:  44%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 220/500 [15:28<16:59,  3.64s/it]
# Inference:  44%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 221/500 [15:34<20:10,  4.34s/it]
# Inference:  44%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 222/500 [15:41<23:42,  5.12s/it]
# Inference:  45%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 223/500 [15:45<22:45,  4.93s/it]
# Inference:  45%|â–ˆâ–ˆâ–ˆâ–ˆâ–     | 224/500 [15:49<20:25,  4.44s/it]
# Inference:  45%|â–ˆâ–ˆâ–ˆâ–ˆâ–Œ     | 225/500 [15:53<20:39,  4.51s/it]
# Inference:  45%|â–ˆâ–ˆâ–ˆâ–ˆâ–Œ     | 226/500 [15:57<19:01,  4.17s/it]
# Inference:  45%|â–ˆâ–ˆâ–ˆâ–ˆâ–Œ     | 227/500 [16:02<20:57,  4.61s/it]
# Inference:  46%|â–ˆâ–ˆâ–ˆâ–ˆâ–Œ     | 228/500 [16:10<24:45,  5.46s/it]
# Inference:  46%|â–ˆâ–ˆâ–ˆâ–ˆâ–Œ     | 229/500 [16:15<24:36,  5.45s/it]
# Inference:  46%|â–ˆâ–ˆâ–ˆâ–ˆâ–Œ     | 230/500 [16:19<22:08,  4.92s/it]
# Inference:  46%|â–ˆâ–ˆâ–ˆâ–ˆâ–Œ     | 231/500 [16:22<19:52,  4.43s/it]
# Inference:  46%|â–ˆâ–ˆâ–ˆâ–ˆâ–‹     | 232/500 [16:25<17:57,  4.02s/it]
# Inference:  47%|â–ˆâ–ˆâ–ˆâ–ˆâ–‹     | 233/500 [16:28<16:35,  3.73s/it]
# Inference:  47%|â–ˆâ–ˆâ–ˆâ–ˆâ–‹     | 234/500 [16:33<17:48,  4.02s/it]
# Inference:  47%|â–ˆâ–ˆâ–ˆâ–ˆâ–‹     | 235/500 [16:36<16:28,  3.73s/it]
# Inference:  47%|â–ˆâ–ˆâ–ˆâ–ˆâ–‹     | 236/500 [16:40<17:24,  3.96s/it]
# Inference:  47%|â–ˆâ–ˆâ–ˆâ–ˆâ–‹     | 237/500 [16:43<15:39,  3.57s/it]
# Inference:  48%|â–ˆâ–ˆâ–ˆâ–ˆâ–Š     | 238/500 [16:46<14:26,  3.31s/it]
# Inference:  48%|â–ˆâ–ˆâ–ˆâ–ˆâ–Š     | 239/500 [16:49<14:47,  3.40s/it]
# Inference:  48%|â–ˆâ–ˆâ–ˆâ–ˆâ–Š     | 240/500 [16:53<14:41,  3.39s/it]
# Inference:  48%|â–ˆâ–ˆâ–ˆâ–ˆâ–Š     | 241/500 [16:58<17:13,  3.99s/it]
# Inference:  48%|â–ˆâ–ˆâ–ˆâ–ˆâ–Š     | 242/500 [17:01<16:02,  3.73s/it]
# Inference:  49%|â–ˆâ–ˆâ–ˆâ–ˆâ–Š     | 243/500 [17:07<19:10,  4.48s/it]
# Inference:  49%|â–ˆâ–ˆâ–ˆâ–ˆâ–‰     | 244/500 [17:12<18:51,  4.42s/it]
# Inference:  49%|â–ˆâ–ˆâ–ˆâ–ˆâ–‰     | 245/500 [17:17<19:40,  4.63s/it]
# Inference:  49%|â–ˆâ–ˆâ–ˆâ–ˆâ–‰     | 246/500 [17:23<20:52,  4.93s/it]
# Inference:  49%|â–ˆâ–ˆâ–ˆâ–ˆâ–‰     | 247/500 [17:28<21:39,  5.14s/it]
# Inference:  50%|â–ˆâ–ˆâ–ˆâ–ˆâ–‰     | 248/500 [17:33<20:36,  4.91s/it]
# Inference:  50%|â–ˆâ–ˆâ–ˆâ–ˆâ–‰     | 249/500 [17:36<18:10,  4.35s/it]
# Inference:  50%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆ     | 250/500 [17:39<17:30,  4.20s/it]
# Inference:  50%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆ     | 251/500 [17:43<16:52,  4.07s/it]
# Inference:  50%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆ     | 252/500 [17:47<15:56,  3.86s/it]
# Inference:  51%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆ     | 253/500 [17:50<15:06,  3.67s/it]
# Inference:  51%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆ     | 254/500 [17:53<14:50,  3.62s/it]
# Inference:  51%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆ     | 255/500 [17:58<16:17,  3.99s/it]
# Inference:  51%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆ     | 256/500 [18:02<16:12,  3.98s/it]
# Inference:  51%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 257/500 [18:06<16:18,  4.03s/it]
# Inference:  52%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 258/500 [18:09<14:50,  3.68s/it]
# Inference:  52%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 259/500 [18:12<13:42,  3.41s/it]
# Inference:  52%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 260/500 [18:15<12:56,  3.24s/it]
# Inference:  52%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 261/500 [18:21<15:57,  4.01s/it]
# Inference:  52%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 262/500 [18:26<17:52,  4.50s/it]
# Inference:  53%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž    | 263/500 [18:29<16:01,  4.06s/it]
# Inference:  53%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž    | 264/500 [18:33<15:48,  4.02s/it]
# Inference:  53%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž    | 265/500 [18:37<15:59,  4.08s/it]
# Inference:  53%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž    | 266/500 [18:43<17:11,  4.41s/it]
# Inference:  53%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž    | 267/500 [18:46<16:29,  4.25s/it]
# Inference:  54%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž    | 268/500 [18:52<17:30,  4.53s/it]
# Inference:  54%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 269/500 [18:55<15:48,  4.10s/it]
# Inference:  54%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 270/500 [18:57<14:05,  3.68s/it]
# Inference:  54%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 271/500 [19:02<14:49,  3.89s/it]
# Inference:  54%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 272/500 [19:05<13:45,  3.62s/it]
# Inference:  55%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 273/500 [19:08<12:59,  3.43s/it]
# Inference:  55%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–    | 274/500 [19:12<13:24,  3.56s/it]
# Inference:  55%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ    | 275/500 [19:15<13:21,  3.56s/it]
# Inference:  55%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ    | 276/500 [19:19<13:37,  3.65s/it]
# Inference:  55%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ    | 277/500 [19:23<14:01,  3.77s/it]
# Inference:  56%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ    | 278/500 [19:26<13:17,  3.59s/it]
# Inference:  56%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ    | 279/500 [19:29<12:27,  3.38s/it]
# Inference:  56%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ    | 280/500 [19:32<11:41,  3.19s/it]
# Inference:  56%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ    | 281/500 [19:35<11:24,  3.13s/it]
# Inference:  56%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹    | 282/500 [19:38<11:25,  3.15s/it]
# Inference:  57%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹    | 283/500 [19:41<11:29,  3.18s/it]
# Inference:  57%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹    | 284/500 [19:45<11:59,  3.33s/it]
# Inference:  57%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹    | 285/500 [19:49<12:31,  3.50s/it]
# Inference:  57%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹    | 286/500 [19:53<12:55,  3.62s/it]
# Inference:  57%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹    | 287/500 [19:56<12:54,  3.64s/it]
# Inference:  58%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š    | 288/500 [20:00<13:06,  3.71s/it]
# Inference:  58%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š    | 289/500 [20:04<13:27,  3.83s/it]
# Inference:  58%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š    | 290/500 [20:07<12:15,  3.50s/it]
# Inference:  58%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š    | 291/500 [20:10<11:45,  3.37s/it]
# Inference:  58%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š    | 292/500 [20:14<11:34,  3.34s/it]
# Inference:  59%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š    | 293/500 [20:18<12:45,  3.70s/it]
# Inference:  59%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰    | 294/500 [20:24<14:30,  4.23s/it]
# Inference:  59%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰    | 295/500 [20:26<13:06,  3.84s/it]
# Inference:  59%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰    | 296/500 [20:31<13:49,  4.07s/it]
# Inference:  59%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰    | 297/500 [20:35<13:20,  3.95s/it]
# Inference:  60%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰    | 298/500 [20:38<12:08,  3.60s/it]
# Inference:  60%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰    | 299/500 [20:42<12:49,  3.83s/it]
# Inference:  60%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ    | 300/500 [20:45<12:33,  3.77s/it]
# Inference:  60%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ    | 301/500 [20:52<15:28,  4.66s/it]
# Inference:  60%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ    | 302/500 [20:58<16:26,  4.98s/it]
# Inference:  61%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ    | 303/500 [21:03<16:37,  5.06s/it]
# Inference:  61%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ    | 304/500 [21:07<14:56,  4.58s/it]
# Inference:  61%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ    | 305/500 [21:10<13:30,  4.16s/it]
# Inference:  61%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ    | 306/500 [21:16<15:17,  4.73s/it]
# Inference:  61%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 307/500 [21:19<13:22,  4.16s/it]
# Inference:  62%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 308/500 [21:25<15:31,  4.85s/it]
# Inference:  62%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 309/500 [21:28<13:47,  4.33s/it]
# Inference:  62%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 310/500 [21:32<13:10,  4.16s/it]
# Inference:  62%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 311/500 [21:36<12:46,  4.06s/it]
# Inference:  62%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 312/500 [21:39<11:56,  3.81s/it]
# Inference:  63%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž   | 313/500 [21:42<11:20,  3.64s/it]
# Inference:  63%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž   | 314/500 [21:47<11:55,  3.85s/it]
# Inference:  63%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž   | 315/500 [21:50<11:05,  3.60s/it]
# Inference:  63%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž   | 316/500 [21:54<11:14,  3.66s/it]
# Inference:  63%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž   | 317/500 [21:58<11:32,  3.78s/it]
# Inference:  64%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž   | 318/500 [22:02<12:17,  4.05s/it]
# Inference:  64%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 319/500 [22:05<11:18,  3.75s/it]
# Inference:  64%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 320/500 [22:09<11:11,  3.73s/it]
# Inference:  64%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 321/500 [22:12<10:10,  3.41s/it]
# Inference:  64%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 322/500 [22:18<12:38,  4.26s/it]
# Inference:  65%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 323/500 [22:21<11:28,  3.89s/it]
# Inference:  65%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–   | 324/500 [22:24<10:36,  3.62s/it]
# Inference:  65%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ   | 325/500 [22:30<12:19,  4.22s/it]
# Inference:  65%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ   | 326/500 [22:33<11:11,  3.86s/it]
# Inference:  65%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ   | 327/500 [22:37<11:21,  3.94s/it]
# Inference:  66%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ   | 328/500 [22:40<10:57,  3.83s/it]
# Inference:  66%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ   | 329/500 [22:46<12:09,  4.27s/it]
# Inference:  66%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ   | 330/500 [22:49<11:26,  4.04s/it]
# Inference:  66%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ   | 331/500 [22:52<10:20,  3.67s/it]
# Inference:  66%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹   | 332/500 [22:55<09:30,  3.39s/it]
# Inference:  67%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹   | 333/500 [23:01<12:12,  4.39s/it]
# Inference:  67%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹   | 334/500 [23:07<12:49,  4.63s/it]
# Inference:  67%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹   | 335/500 [23:11<12:22,  4.50s/it]
# Inference:  67%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹   | 336/500 [23:14<11:01,  4.03s/it]
# Inference:  67%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹   | 337/500 [23:17<10:27,  3.85s/it]
# Inference:  68%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š   | 338/500 [23:20<09:45,  3.61s/it]
# Inference:  68%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š   | 339/500 [23:26<11:09,  4.16s/it]
# Inference:  68%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š   | 340/500 [23:29<10:39,  4.00s/it]
# Inference:  68%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š   | 341/500 [23:37<13:13,  4.99s/it]
# Inference:  68%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š   | 342/500 [23:42<13:47,  5.24s/it]
# Inference:  69%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š   | 343/500 [23:46<12:11,  4.66s/it]
# Inference:  69%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰   | 344/500 [23:49<11:27,  4.41s/it]
# Inference:  69%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰   | 345/500 [23:53<10:36,  4.10s/it]
# Inference:  69%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰   | 346/500 [23:56<09:47,  3.81s/it]
# Inference:  69%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰   | 347/500 [23:59<09:01,  3.54s/it]
# Inference:  70%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰   | 348/500 [24:02<08:27,  3.34s/it]
# Inference:  70%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰   | 349/500 [24:06<09:05,  3.61s/it]
# Inference:  70%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ   | 350/500 [24:09<08:19,  3.33s/it]
# Inference:  70%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ   | 351/500 [24:12<08:26,  3.40s/it]
# Inference:  70%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ   | 352/500 [24:20<11:15,  4.57s/it]
# Inference:  71%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ   | 353/500 [24:24<11:24,  4.66s/it]
# Inference:  71%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ   | 354/500 [24:30<12:22,  5.09s/it]
# Inference:  71%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ   | 355/500 [24:33<10:41,  4.43s/it]
# Inference:  71%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ   | 356/500 [24:38<11:07,  4.63s/it]
# Inference:  71%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 357/500 [24:42<09:57,  4.18s/it]
# Inference:  72%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 358/500 [24:45<09:16,  3.92s/it]
# Inference:  72%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 359/500 [24:50<10:13,  4.35s/it]
# Inference:  72%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 360/500 [24:53<09:11,  3.94s/it]
# Inference:  72%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 361/500 [24:57<09:01,  3.89s/it]
# Inference:  72%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 362/500 [25:01<08:40,  3.77s/it]
# Inference:  73%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž  | 363/500 [25:04<08:12,  3.60s/it]
# Inference:  73%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž  | 364/500 [25:08<08:31,  3.76s/it]
# Inference:  73%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž  | 365/500 [25:11<08:11,  3.64s/it]
# Inference:  73%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž  | 366/500 [25:15<08:09,  3.65s/it]
# Inference:  73%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž  | 367/500 [25:21<09:24,  4.25s/it]
# Inference:  74%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž  | 368/500 [25:24<09:01,  4.10s/it]
# Inference:  74%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 369/500 [25:30<09:44,  4.46s/it]
# Inference:  74%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 370/500 [25:34<09:34,  4.42s/it]
# Inference:  74%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 371/500 [25:41<10:59,  5.11s/it]
# Inference:  74%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 372/500 [25:45<10:33,  4.95s/it]
# Inference:  75%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 373/500 [25:48<09:23,  4.43s/it]
# Inference:  75%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–  | 374/500 [25:51<08:17,  3.95s/it]
# Inference:  75%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ  | 375/500 [25:55<08:05,  3.89s/it]
# Inference:  75%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ  | 376/500 [25:58<07:19,  3.55s/it]
# Inference:  75%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ  | 377/500 [26:01<07:17,  3.56s/it]
# Inference:  76%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ  | 378/500 [26:04<06:44,  3.32s/it]
# Inference:  76%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ  | 379/500 [26:09<07:36,  3.78s/it]
# Inference:  76%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ  | 380/500 [26:12<07:01,  3.51s/it]
# Inference:  76%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ  | 381/500 [26:16<07:31,  3.79s/it]
# Inference:  76%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹  | 382/500 [26:22<08:18,  4.22s/it]
# Inference:  77%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹  | 383/500 [26:27<09:11,  4.71s/it]
# Inference:  77%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹  | 384/500 [26:32<08:48,  4.56s/it]
# Inference:  77%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹  | 385/500 [26:35<08:16,  4.32s/it]
# Inference:  77%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹  | 386/500 [26:39<07:37,  4.01s/it]
# Inference:  77%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹  | 387/500 [26:43<07:39,  4.07s/it]
# Inference:  78%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š  | 388/500 [26:46<06:51,  3.68s/it]
# Inference:  78%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š  | 389/500 [26:49<06:41,  3.62s/it]
# Inference:  78%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š  | 390/500 [26:55<07:43,  4.21s/it]
# Inference:  78%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š  | 391/500 [26:58<07:03,  3.89s/it]
# Inference:  78%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š  | 392/500 [27:01<06:31,  3.63s/it]
# Inference:  79%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š  | 393/500 [27:07<08:04,  4.53s/it]
# Inference:  79%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰  | 394/500 [27:13<08:35,  4.86s/it]
# Inference:  79%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰  | 395/500 [27:17<08:03,  4.60s/it]
# Inference:  79%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰  | 396/500 [27:22<08:03,  4.65s/it]
# Inference:  79%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰  | 397/500 [27:25<07:21,  4.29s/it]
# Inference:  80%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰  | 398/500 [27:31<07:51,  4.62s/it]
# Inference:  80%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰  | 399/500 [27:35<07:36,  4.52s/it]
# Inference:  80%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ  | 400/500 [27:41<08:12,  4.93s/it]
# Inference:  80%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ  | 401/500 [27:44<07:15,  4.40s/it]
# Inference:  80%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ  | 402/500 [27:48<07:04,  4.33s/it]
# Inference:  81%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ  | 403/500 [27:51<06:23,  3.95s/it]
# Inference:  81%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ  | 404/500 [27:55<06:08,  3.83s/it]
# Inference:  81%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ  | 405/500 [27:58<05:33,  3.51s/it]
# Inference:  81%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ  | 406/500 [28:01<05:17,  3.37s/it]
# Inference:  81%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 407/500 [28:05<05:29,  3.54s/it]
# Inference:  82%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 408/500 [28:09<05:43,  3.73s/it]
# Inference:  82%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 409/500 [28:12<05:35,  3.68s/it]
# Inference:  82%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 410/500 [28:15<05:07,  3.42s/it]
# Inference:  82%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 411/500 [28:20<05:31,  3.73s/it]
# Inference:  82%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 412/500 [28:24<05:50,  3.98s/it]
# Inference:  83%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž | 413/500 [28:29<06:19,  4.36s/it]
# Inference:  83%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž | 414/500 [28:33<05:46,  4.03s/it]
# Inference:  83%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž | 415/500 [28:38<06:20,  4.47s/it]
# Inference:  83%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž | 416/500 [28:41<05:30,  3.93s/it]
# Inference:  83%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž | 417/500 [28:46<06:01,  4.35s/it]
# Inference:  84%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž | 418/500 [28:49<05:26,  3.98s/it]
# Inference:  84%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 419/500 [28:52<04:55,  3.65s/it]
# Inference:  84%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 420/500 [28:56<04:54,  3.68s/it]
# Inference:  84%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 421/500 [28:59<04:44,  3.60s/it]
# Inference:  84%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 422/500 [29:03<04:38,  3.57s/it]
# Inference:  85%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 423/500 [29:07<04:37,  3.61s/it]
# Inference:  85%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ– | 424/500 [29:09<04:14,  3.35s/it]
# Inference:  85%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ | 425/500 [29:13<04:14,  3.40s/it]
# Inference:  85%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ | 426/500 [29:17<04:22,  3.54s/it]
# Inference:  85%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ | 427/500 [29:20<04:24,  3.62s/it]
# Inference:  86%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ | 428/500 [29:23<04:05,  3.42s/it]
# Inference:  86%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ | 429/500 [29:27<04:00,  3.39s/it]
# Inference:  86%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ | 430/500 [29:30<04:04,  3.49s/it]
# Inference:  86%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ | 431/500 [29:36<04:42,  4.09s/it]
# Inference:  86%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹ | 432/500 [29:39<04:16,  3.77s/it]
# Inference:  87%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹ | 433/500 [29:42<03:50,  3.44s/it]
# Inference:  87%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹ | 434/500 [29:45<03:53,  3.54s/it]
# Inference:  87%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹ | 435/500 [29:51<04:39,  4.30s/it]
# Inference:  87%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹ | 436/500 [29:57<04:55,  4.62s/it]
# Inference:  87%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹ | 437/500 [30:00<04:29,  4.28s/it]
# Inference:  88%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š | 438/500 [30:03<04:04,  3.94s/it]
# Inference:  88%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š | 439/500 [30:08<04:06,  4.03s/it]
# Inference:  88%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š | 440/500 [30:12<03:58,  3.97s/it]
# Inference:  88%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š | 441/500 [30:15<03:44,  3.81s/it]
# Inference:  88%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š | 442/500 [30:18<03:29,  3.62s/it]
# Inference:  89%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š | 443/500 [30:22<03:22,  3.56s/it]
# Inference:  89%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰ | 444/500 [30:26<03:32,  3.79s/it]
# Inference:  89%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰ | 445/500 [30:29<03:16,  3.56s/it]
# Inference:  89%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰ | 446/500 [30:33<03:25,  3.81s/it]
# Inference:  89%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰ | 447/500 [30:36<03:09,  3.57s/it]
# Inference:  90%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰ | 448/500 [30:40<03:05,  3.57s/it]
# Inference:  90%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰ | 449/500 [30:45<03:18,  3.88s/it]
# Inference:  90%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ | 450/500 [30:47<02:57,  3.55s/it]
# Inference:  90%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ | 451/500 [30:53<03:23,  4.15s/it]
# Inference:  90%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ | 452/500 [30:56<02:59,  3.73s/it]
# Inference:  91%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ | 453/500 [30:59<02:52,  3.66s/it]
# Inference:  91%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ | 454/500 [31:02<02:36,  3.41s/it]
# Inference:  91%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ | 455/500 [31:06<02:46,  3.69s/it]
# Inference:  91%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ | 456/500 [31:10<02:48,  3.82s/it]
# Inference:  91%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 457/500 [31:13<02:30,  3.50s/it]
# Inference:  92%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 458/500 [31:16<02:24,  3.44s/it]
# Inference:  92%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 459/500 [31:21<02:30,  3.68s/it]
# Inference:  92%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 460/500 [31:24<02:17,  3.43s/it]
# Inference:  92%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 461/500 [31:28<02:28,  3.81s/it]
# Inference:  92%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 462/500 [31:31<02:13,  3.52s/it]
# Inference:  93%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž| 463/500 [31:34<02:07,  3.44s/it]
# Inference:  93%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž| 464/500 [31:41<02:36,  4.33s/it]
# Inference:  93%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž| 465/500 [31:45<02:26,  4.20s/it]
# Inference:  93%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž| 466/500 [31:50<02:35,  4.57s/it]
# Inference:  93%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž| 467/500 [31:56<02:41,  4.90s/it]
# Inference:  94%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Ž| 468/500 [31:59<02:21,  4.43s/it]
# Inference:  94%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 469/500 [32:03<02:09,  4.16s/it]
# Inference:  94%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 470/500 [32:07<02:02,  4.09s/it]
# Inference:  94%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 471/500 [32:12<02:14,  4.65s/it]
# Inference:  94%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 472/500 [32:18<02:16,  4.89s/it]
# Inference:  95%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 473/500 [32:23<02:11,  4.86s/it]
# Inference:  95%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–| 474/500 [32:27<02:01,  4.65s/it]
# Inference:  95%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ| 475/500 [32:30<01:43,  4.14s/it]
# Inference:  95%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ| 476/500 [32:35<01:43,  4.32s/it]
# Inference:  95%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ| 477/500 [32:38<01:33,  4.07s/it]
# Inference:  96%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ| 478/500 [32:42<01:28,  4.02s/it]
# Inference:  96%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ| 479/500 [32:47<01:29,  4.26s/it]
# Inference:  96%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ| 480/500 [32:51<01:25,  4.28s/it]
# Inference:  96%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Œ| 481/500 [32:54<01:14,  3.94s/it]
# Inference:  96%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹| 482/500 [32:58<01:11,  3.98s/it]
# Inference:  97%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹| 483/500 [33:02<01:08,  4.00s/it]
# Inference:  97%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹| 484/500 [33:07<01:09,  4.32s/it]
# Inference:  97%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹| 485/500 [33:12<01:07,  4.48s/it]
# Inference:  97%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹| 486/500 [33:19<01:12,  5.18s/it]
# Inference:  97%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‹| 487/500 [33:24<01:07,  5.20s/it]
# Inference:  98%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š| 488/500 [33:28<00:57,  4.83s/it]
# Inference:  98%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š| 489/500 [33:32<00:48,  4.41s/it]
# Inference:  98%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š| 490/500 [33:38<00:48,  4.87s/it]
# Inference:  98%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š| 491/500 [33:45<00:49,  5.53s/it]
# Inference:  98%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š| 492/500 [33:50<00:42,  5.31s/it]
# Inference:  99%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–Š| 493/500 [33:55<00:37,  5.42s/it]
# Inference:  99%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰| 494/500 [33:59<00:29,  4.99s/it]
# Inference:  99%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰| 495/500 [34:03<00:23,  4.63s/it]
# Inference:  99%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰| 496/500 [34:06<00:16,  4.05s/it]
# Inference:  99%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰| 497/500 [34:09<00:11,  3.92s/it]
# Inference: 100%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰| 498/500 [34:14<00:08,  4.05s/it]
# Inference: 100%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‰| 499/500 [34:17<00:03,  3.88s/it]
# Inference: 100%|â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆ| 500/500 [34:22<00:00,  4.13s/it]
# === DONE: Text + Audio experiment complete ===

# %%
from google.colab import files

files.download("cache/phase3_text_audio_raw.jsonl")
files.download("cache/phase3_text_audio_raw.heterographic.jsonl")
files.download("cache/phase3_text_audio_raw.homographic.jsonl")

# %%
# !which piper
# !piper --help
